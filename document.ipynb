# %% [markdown]
# ## Document Intelligence
# ### OCR/Read

# %%
endpoint = "https://1sesac035-document-intelligence.cognitiveservices.azure.com/"
key = "AF925XNi89GEygFNxyYYOLUQv00Dz0YPI7VfLqxJU0DLfdhKGrS7JQQJ99BFACi5YpzXJ3w3AAALACOGTyi7"

# %%
pip install azure-ai-documentintelligence
# Out:
# Requirement already satisfied: azure-ai-documentintelligence in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (1.0.2)
# Requirement already satisfied: isodate>=0.6.1 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from azure-ai-documentintelligence) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from azure-ai-documentintelligence) (1.34.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from azure-ai-documentintelligence) (4.13.2)
# Requirement already satisfied: requests>=2.21.0 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from azure-core>=1.30.0->azure-ai-documentintelligence) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from azure-core>=1.30.0->azure-ai-documentintelligence) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/py313/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-documentintelligence) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
This code sample shows Prebuilt Read operations with the Azure AI Document Intelligence client library.
The async versions of the samples require Python 3.8 or later.

To learn more, please visit the documentation - Quickstart: Document Intelligence (formerly Form Recognizer) SDKs
https://learn.microsoft.com/azure/ai-services/document-intelligence/quickstarts/get-started-sdks-rest-api?pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeDocumentRequest
import numpy as np

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    reshaped_bounding_box = np.array(bounding_box).reshape(-1, 2)
    return ", ".join(["[{}, {}]".format(x, y) for x, y in reshaped_bounding_box])

def analyze_read():
    # sample document
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"

    document_intelligence_client  = DocumentIntelligenceClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_intelligence_client.begin_analyze_document(
        "prebuilt-read", AnalyzeDocumentRequest(url_source=formUrl)
    )
    result = poller.result()

    print ("Document contains content: ", result.content)

    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  UNITED STATES SECURITIES AND EXCHANGE COMMISSION Washington, D.C. 20549
# FORM 10-Q
# ☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
# For the Quarterly Period Ended March 31, 2020
# OR
# ☐ TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
# For the Transition Period From to Commission File Number 001-37845
# MICROSOFT CORPORATION
# WASHINGTON (STATE OF INCORPORATION) ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399 (425) 882-8080 www.microsoft.com/investor
# 91-1144442 (I.R.S. ID)
# Securities registered pursuant to Section 12(b) of the Act:
# Title of each class
# Trading Symbol
# Name of exchange on which registered
# Common stock, $0.00000625 par value per share
# MSFT
# NASDAQ
# 2.125% Notes due 2021
# MSFT
# NASDAQ
# 3.125% Notes due 2028
# MSFT
# NASDAQ
# 2.625% Notes due 2033
# MSFT
# NASDAQ
# Securities registered pursuant to Section 12(g) of the Act:
# NONE
# Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days. Yes No
# Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files). Yes No
# Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth company. See the definitions of "large accelerated filer," "accelerated filer," "smaller reporting company," and "emerging growth company" in Rule 12b-2 of the Exchange Act.
# Large accelerated filer
# Non-accelerated filer
# Accelerated filer Smaller reporting company Emerging growth company
# If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.
# Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).
# Yes
# No
# Indicate the number of shares outstanding of each of the issuer's classes of common stock, as of the latest practicable date.
# Class
# Outstanding as of April 24, 2020
# Common Stock, $0.00000625 par value per share
# 7,583,440,247 shares
# ----Analyzing Read from page #1----
# Page has width: 8.5 and height: 11.0, measured with unit: LengthUnit.INCH
# ...Line # 0 has text content 'UNITED STATES' within bounding box '[3.4669, 0.6636], [5.0236, 0.6636], [5.0236, 0.8403], [3.4669, 0.8403]'
# ...Line # 1 has text content 'SECURITIES AND EXCHANGE COMMISSION' within bounding box '[2.1728, 0.8785], [6.3177, 0.8785], [6.3177, 1.0647], [2.1728, 1.0647]'
# ...Line # 2 has text content 'Washington, D.C. 20549' within bounding box '[3.443, 1.0933], [5.0475, 1.0933], [5.0475, 1.2413], [3.443, 1.2461]'
# ...Line # 3 has text content 'FORM 10-Q' within bounding box '[3.7008, 1.3893], [4.7896, 1.3941], [4.7896, 1.5803], [3.7008, 1.5803]'
# ...Line # 4 has text content '☒' within bounding box '[0.6694, 1.7746], [0.7764, 1.7746], [0.7764, 1.8833], [0.6694, 1.8833]'
# ...Line # 5 has text content 'QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF' within bounding box '[0.9646, 1.7426], [7.8649, 1.7426], [7.8649, 1.9097], [0.9646, 1.9097]'
# ...Line # 6 has text content '1934' within bounding box '[0.9837, 1.9288], [1.3084, 1.9336], [1.3084, 2.0625], [0.9837, 2.0673]'
# ...Line # 7 has text content 'For the Quarterly Period Ended March 31, 2020' within bounding box '[0.9742, 2.1341], [3.4669, 2.1293], [3.4669, 2.2726], [0.9742, 2.2726]'
# ...Line # 8 has text content 'OR' within bounding box '[4.1211, 2.2582], [4.3407, 2.263], [4.3407, 2.4253], [4.1163, 2.4253]'
# ...Line # 9 has text content '☐' within bounding box '[0.6694, 2.6955], [0.777, 2.6955], [0.777, 2.8042], [0.6694, 2.8042]'
# ...Line # 10 has text content 'TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF' within bounding box '[0.9742, 2.6688], [7.8649, 2.6688], [7.8649, 2.8359], [0.9742, 2.8312]'
# ...Line # 11 has text content '1934' within bounding box '[0.9789, 2.8503], [1.3132, 2.855], [1.3084, 2.9935], [0.9789, 2.9887]'
# ...Line # 12 has text content 'For the Transition Period From' within bounding box '[0.9694, 3.0603], [2.6312, 3.0603], [2.6312, 3.1892], [0.9694, 3.1892]'
# ...Line # 13 has text content 'to' within bounding box '[3.1612, 3.0794], [3.2663, 3.0794], [3.2663, 3.1749], [3.1612, 3.1749]'
# ...Line # 14 has text content 'Commission File Number 001-37845' within bounding box '[3.2281, 3.2418], [5.2767, 3.237], [5.2767, 3.3754], [3.2281, 3.385]'
# ...Line # 15 has text content 'MICROSOFT CORPORATION' within bounding box '[2.5213, 3.5473], [5.9739, 3.5425], [5.9739, 3.7574], [2.5213, 3.7622]'
# ...Line # 16 has text content 'WASHINGTON' within bounding box '[1.9817, 3.934], [2.8222, 3.934], [2.8222, 4.0629], [1.9817, 4.0629]'
# ...Line # 17 has text content '(STATE OF INCORPORATION)' within bounding box '[1.6952, 4.0773], [3.1183, 4.0773], [3.1183, 4.2062], [1.6952, 4.2062]'
# ...Line # 18 has text content 'ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399' within bounding box '[2.5691, 4.2491], [5.9213, 4.2491], [5.9213, 4.3876], [2.5691, 4.3876]'
# ...Line # 19 has text content '(425) 882-8080' within bounding box '[3.8537, 4.3924], [4.6368, 4.3828], [4.6368, 4.5117], [3.8537, 4.5213]'
# ...Line # 20 has text content 'www.microsoft.com/investor' within bounding box '[3.4716, 4.5213], [5.014, 4.5165], [5.014, 4.6406], [3.4716, 4.6454]'
# ...Line # 21 has text content '91-1144442' within bounding box '[5.7542, 3.9388], [6.4084, 3.9388], [6.4084, 4.0677], [5.7542, 4.0677]'
# ...Line # 22 has text content '(I.R.S. ID)' within bounding box '[5.8593, 4.082], [6.3177, 4.0868], [6.3177, 4.2014], [5.8593, 4.1966]'
# ...Line # 23 has text content 'Securities registered pursuant to Section 12(b) of the Act:' within bounding box '[0.6112, 4.7218], [3.6292, 4.717], [3.634, 4.8507], [0.6112, 4.8555]'
# ...Line # 24 has text content 'Title of each class' within bounding box '[0.6112, 4.951], [1.5758, 4.951], [1.5758, 5.0799], [0.6112, 5.0799]'
# ...Line # 25 has text content 'Trading Symbol' within bounding box '[4.3264, 4.951], [5.1812, 4.951], [5.1812, 5.0846], [4.3264, 5.0846]'
# ...Line # 26 has text content 'Name of exchange on which registered' within bounding box '[5.568, 4.9462], [7.6357, 4.951], [7.6357, 5.0846], [5.568, 5.0846]'
# ...Line # 27 has text content 'Common stock, $0.00000625 par value per share' within bounding box '[0.616, 5.1515], [3.3618, 5.1563], [3.3618, 5.2947], [0.616, 5.2852]'
# ...Line # 28 has text content 'MSFT' within bounding box '[4.5843, 5.1515], [4.9185, 5.1515], [4.9185, 5.2708], [4.5795, 5.2708]'
# ...Line # 29 has text content 'NASDAQ' within bounding box '[6.3416, 5.1563], [6.8669, 5.1515], [6.8716, 5.2708], [6.3416, 5.2756]'
# ...Line # 30 has text content '2.125% Notes due 2021' within bounding box '[0.6065, 5.309], [1.9292, 5.309], [1.9292, 5.4379], [0.6065, 5.4379]'
# ...Line # 31 has text content 'MSFT' within bounding box '[4.5795, 5.309], [4.9233, 5.3138], [4.9233, 5.4284], [4.5747, 5.4284]'
# ...Line # 32 has text content 'NASDAQ' within bounding box '[6.3225, 5.2899], [6.8764, 5.2899], [6.8764, 5.4523], [6.3225, 5.457]'
# ...Line # 33 has text content '3.125% Notes due 2028' within bounding box '[0.616, 5.4714], [1.934, 5.4714], [1.934, 5.605], [0.616, 5.605]'
# ...Line # 34 has text content 'MSFT' within bounding box '[4.5795, 5.4714], [4.9233, 5.4714], [4.9233, 5.5907], [4.5747, 5.5907]'
# ...Line # 35 has text content 'NASDAQ' within bounding box '[6.3368, 5.4714], [6.8669, 5.4714], [6.8669, 5.6003], [6.3368, 5.5955]'
# ...Line # 36 has text content '2.625% Notes due 2033' within bounding box '[0.6065, 5.6337], [1.934, 5.6289], [1.934, 5.753], [0.6065, 5.7578]'
# ...Line # 37 has text content 'MSFT' within bounding box '[4.5747, 5.6337], [4.9185, 5.6289], [4.9185, 5.753], [4.5747, 5.753]'
# ...Line # 38 has text content 'NASDAQ' within bounding box '[6.3368, 5.6289], [6.8716, 5.6289], [6.8764, 5.753], [6.3368, 5.753]'
# ...Line # 39 has text content 'Securities registered pursuant to Section 12(g) of the Act:' within bounding box '[0.616, 5.8247], [3.6292, 5.8247], [3.6292, 5.9631], [0.616, 5.9631]'
# ...Line # 40 has text content 'NONE' within bounding box '[0.616, 6.0586], [0.9742, 6.0586], [0.9742, 6.1732], [0.616, 6.1732]'
# ...Line # 41 has text content 'Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange' within bounding box '[0.6351, 6.2448], [7.8553, 6.2448], [7.8553, 6.3832], [0.6351, 6.3832]'
# ...Line # 42 has text content 'Act of 1934 during the preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has' within bounding box '[0.6351, 6.3832], [7.8506, 6.3832], [7.8506, 6.5217], [0.6351, 6.5169]'
# ...Line # 43 has text content 'been subject to such filing requirements for the past 90 days.' within bounding box '[0.6303, 6.5265], [3.8298, 6.5265], [3.8298, 6.6697], [0.6303, 6.6697]'
# ...Line # 44 has text content 'Yes' within bounding box '[3.9396, 6.536], [4.164, 6.5456], [4.164, 6.6411], [3.9396, 6.6458]'
# ...Line # 45 has text content 'No' within bounding box '[4.4792, 6.5408], [4.6272, 6.5408], [4.6272, 6.6363], [4.4744, 6.6363]'
# ...Line # 46 has text content 'Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule' within bounding box '[0.6399, 6.727], [7.8553, 6.727], [7.8553, 6.8607], [0.6399, 6.8607]'
# ...Line # 47 has text content '405 of Regulation S-T (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to' within bounding box '[0.6399, 6.8607], [7.8601, 6.8655], [7.8601, 6.9991], [0.6399, 6.9944]'
# ...Line # 48 has text content 'submit such files).' within bounding box '[0.6303, 7.0135], [1.6045, 7.0135], [1.6045, 7.1376], [0.6303, 7.1376]'
# ...Line # 49 has text content 'Yes' within bounding box '[1.6618, 7.0182], [1.9053, 7.023], [1.9006, 7.1185], [1.6618, 7.1233]'
# ...Line # 50 has text content 'No' within bounding box '[2.1966, 7.023], [2.3542, 7.023], [2.3494, 7.1185], [2.1966, 7.1185]'
# ...Line # 51 has text content 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting' within bounding box '[0.6208, 7.2044], [7.8506, 7.2044], [7.8506, 7.3429], [0.6208, 7.3429]'
# ...Line # 52 has text content 'company, or an emerging growth company. See the definitions of "large accelerated filer," "accelerated filer," "smaller reporting company,"' within bounding box '[0.6351, 7.3477], [7.8601, 7.3429], [7.8601, 7.4861], [0.6351, 7.4909]'
# ...Line # 53 has text content 'and "emerging growth company" in Rule 12b-2 of the Exchange Act.' within bounding box '[0.6351, 7.4813], [4.2118, 7.4766], [4.2118, 7.615], [0.6351, 7.6198]'
# ...Line # 54 has text content 'Large accelerated filer' within bounding box '[0.6351, 7.6914], [1.8528, 7.6914], [1.8528, 7.8155], [0.6351, 7.8251]'
# ...Line # 55 has text content 'Non-accelerated filer' within bounding box '[0.6399, 7.8633], [1.7525, 7.8633], [1.7525, 7.997], [0.6399, 7.997]'
# ...Line # 56 has text content 'Accelerated filer' within bounding box '[5.3101, 7.6866], [6.1888, 7.6866], [6.1888, 7.8155], [5.3101, 7.8155]'
# ...Line # 57 has text content 'Smaller reporting company' within bounding box '[5.3197, 7.8681], [6.7618, 7.8776], [6.7618, 8.0065], [5.3197, 7.997]'
# ...Line # 58 has text content 'Emerging growth company' within bounding box '[5.3244, 8.0399], [6.7618, 8.0447], [6.7618, 8.1784], [5.3244, 8.1736]'
# ...Line # 59 has text content 'If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying' within bounding box '[0.6351, 8.2405], [7.8506, 8.2405], [7.8506, 8.3741], [0.6351, 8.3741]'
# ...Line # 60 has text content 'with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.' within bounding box '[0.6351, 8.3885], [6.4992, 8.3885], [6.4992, 8.5317], [0.6351, 8.5317]'
# ...Line # 61 has text content 'Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).' within bounding box '[0.6399, 8.589], [6.3989, 8.589], [6.3989, 8.7322], [0.6399, 8.737]'
# ...Line # 62 has text content 'Yes' within bounding box '[6.5087, 8.6033], [6.7379, 8.6081], [6.7427, 8.7083], [6.5039, 8.7083]'
# ...Line # 63 has text content 'No' within bounding box '[7.0197, 8.6081], [7.1725, 8.6081], [7.1677, 8.7036], [7.0149, 8.7036]'
# ...Line # 64 has text content 'Indicate the number of shares outstanding of each of the issuer's classes of common stock, as of the latest practicable date.' within bounding box '[0.6351, 8.799], [6.9433, 8.799], [6.9433, 8.9375], [0.6351, 8.9327]'
# ...Line # 65 has text content 'Class' within bounding box '[0.6447, 9.0807], [0.9407, 9.0807], [0.936, 9.181], [0.6399, 9.181]'
# ...Line # 66 has text content 'Outstanding as of April 24, 2020' within bounding box '[6.1124, 9.0807], [7.7216, 9.076], [7.7216, 9.2049], [6.1124, 9.2096]'
# ...Line # 67 has text content 'Common Stock, $0.00000625 par value per share' within bounding box '[0.6399, 9.2956], [3.2711, 9.3003], [3.2711, 9.4388], [0.6399, 9.4293]'
# ...Line # 68 has text content '7,583,440,247 shares' within bounding box '[6.5421, 9.3147], [7.7264, 9.3194], [7.7264, 9.4531], [6.5421, 9.4531]'
# ...Word 'UNITED' has a confidence of 0.997
# ...Word 'STATES' has a confidence of 0.998
# ...Word 'SECURITIES' has a confidence of 0.993
# ...Word 'AND' has a confidence of 0.999
# ...Word 'EXCHANGE' has a confidence of 0.993
# ...Word 'COMMISSION' has a confidence of 0.993
# ...Word 'Washington,' has a confidence of 0.995
# ...Word 'D.C.' has a confidence of 0.995
# ...Word '20549' has a confidence of 0.998
# ...Word 'FORM' has a confidence of 0.992
# ...Word '10-Q' has a confidence of 0.992
# ...Word '☒' has a confidence of 1.0
# ...Word 'QUARTERLY' has a confidence of 0.994
# ...Word 'REPORT' has a confidence of 0.996
# ...Word 'PURSUANT' has a confidence of 0.992
# ...Word 'TO' has a confidence of 0.997
# ...Word 'SECTION' has a confidence of 0.994
# ...Word '13' has a confidence of 0.993
# ...Word 'OR' has a confidence of 0.998
# ...Word '15(d)' has a confidence of 0.994
# ...Word 'OF' has a confidence of 0.99
# ...Word 'THE' has a confidence of 0.998
# ...Word 'SECURITIES' has a confidence of 0.993
# ...Word 'EXCHANGE' has a confidence of 0.994
# ...Word 'ACT' has a confidence of 0.997
# ...Word 'OF' has a confidence of 0.998
# ...Word '1934' has a confidence of 0.988
# ...Word 'For' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.998
# ...Word 'Quarterly' has a confidence of 0.995
# ...Word 'Period' has a confidence of 0.997
# ...Word 'Ended' has a confidence of 0.997
# ...Word 'March' has a confidence of 0.997
# ...Word '31,' has a confidence of 0.993
# ...Word '2020' has a confidence of 0.989
# ...Word 'OR' has a confidence of 0.992
# ...Word '☐' has a confidence of 1.0
# ...Word 'TRANSITION' has a confidence of 0.992
# ...Word 'REPORT' has a confidence of 0.995
# ...Word 'PURSUANT' has a confidence of 0.995
# ...Word 'TO' has a confidence of 0.996
# ...Word 'SECTION' has a confidence of 0.992
# ...Word '13' has a confidence of 0.994
# ...Word 'OR' has a confidence of 0.998
# ...Word '15(d)' has a confidence of 0.989
# ...Word 'OF' has a confidence of 0.995
# ...Word 'THE' has a confidence of 0.996
# ...Word 'SECURITIES' has a confidence of 0.992
# ...Word 'EXCHANGE' has a confidence of 0.992
# ...Word 'ACT' has a confidence of 0.996
# ...Word 'OF' has a confidence of 0.999
# ...Word '1934' has a confidence of 0.989
# ...Word 'For' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.999
# ...Word 'Transition' has a confidence of 0.995
# ...Word 'Period' has a confidence of 0.997
# ...Word 'From' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.995
# ...Word 'Commission' has a confidence of 0.994
# ...Word 'File' has a confidence of 0.993
# ...Word 'Number' has a confidence of 0.992
# ...Word '001-37845' has a confidence of 0.992
# ...Word 'MICROSOFT' has a confidence of 0.994
# ...Word 'CORPORATION' has a confidence of 0.992
# ...Word 'WASHINGTON' has a confidence of 0.996
# ...Word '(STATE' has a confidence of 0.995
# ...Word 'OF' has a confidence of 0.997
# ...Word 'INCORPORATION)' has a confidence of 0.989
# ...Word 'ONE' has a confidence of 0.998
# ...Word 'MICROSOFT' has a confidence of 0.989
# ...Word 'WAY,' has a confidence of 0.989
# ...Word 'REDMOND,' has a confidence of 0.993
# ...Word 'WASHINGTON' has a confidence of 0.992
# ...Word '98052-6399' has a confidence of 0.993
# ...Word '(425)' has a confidence of 0.995
# ...Word '882-8080' has a confidence of 0.994
# ...Word 'www.microsoft.com/investor' has a confidence of 0.99
# ...Word '91-1144442' has a confidence of 0.995
# ...Word '(I.R.S.' has a confidence of 0.924
# ...Word 'ID)' has a confidence of 0.992
# ...Word 'Securities' has a confidence of 0.993
# ...Word 'registered' has a confidence of 0.992
# ...Word 'pursuant' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.997
# ...Word 'Section' has a confidence of 0.995
# ...Word '12(b)' has a confidence of 0.992
# ...Word 'of' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.998
# ...Word 'Act:' has a confidence of 0.99
# ...Word 'Title' has a confidence of 0.996
# ...Word 'of' has a confidence of 0.997
# ...Word 'each' has a confidence of 0.992
# ...Word 'class' has a confidence of 0.996
# ...Word 'Trading' has a confidence of 0.998
# ...Word 'Symbol' has a confidence of 0.996
# ...Word 'Name' has a confidence of 0.992
# ...Word 'of' has a confidence of 0.997
# ...Word 'exchange' has a confidence of 0.995
# ...Word 'on' has a confidence of 0.999
# ...Word 'which' has a confidence of 0.998
# ...Word 'registered' has a confidence of 0.995
# ...Word 'Common' has a confidence of 0.996
# ...Word 'stock,' has a confidence of 0.995
# ...Word '$0.00000625' has a confidence of 0.992
# ...Word 'par' has a confidence of 0.999
# ...Word 'value' has a confidence of 0.997
# ...Word 'per' has a confidence of 0.999
# ...Word 'share' has a confidence of 0.997
# ...Word 'MSFT' has a confidence of 0.991
# ...Word 'NASDAQ' has a confidence of 0.996
# ...Word '2.125%' has a confidence of 0.993
# ...Word 'Notes' has a confidence of 0.995
# ...Word 'due' has a confidence of 0.995
# ...Word '2021' has a confidence of 0.99
# ...Word 'MSFT' has a confidence of 0.989
# ...Word 'NASDAQ' has a confidence of 0.994
# ...Word '3.125%' has a confidence of 0.996
# ...Word 'Notes' has a confidence of 0.995
# ...Word 'due' has a confidence of 0.997
# ...Word '2028' has a confidence of 0.989
# ...Word 'MSFT' has a confidence of 0.992
# ...Word 'NASDAQ' has a confidence of 0.995
# ...Word '2.625%' has a confidence of 0.994
# ...Word 'Notes' has a confidence of 0.996
# ...Word 'due' has a confidence of 0.998
# ...Word '2033' has a confidence of 0.991
# ...Word 'MSFT' has a confidence of 0.99
# ...Word 'NASDAQ' has a confidence of 0.995
# ...Word 'Securities' has a confidence of 0.993
# ...Word 'registered' has a confidence of 0.992
# ...Word 'pursuant' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.998
# ...Word 'Section' has a confidence of 0.995
# ...Word '12(g)' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.998
# ...Word 'the' has a confidence of 0.998
# ...Word 'Act:' has a confidence of 0.989
# ...Word 'NONE' has a confidence of 0.99
# ...Word 'Indicate' has a confidence of 0.992
# ...Word 'by' has a confidence of 0.992
# ...Word 'check' has a confidence of 0.996
# ...Word 'mark' has a confidence of 0.992
# ...Word 'whether' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.998
# ...Word 'registrant' has a confidence of 0.992
# ...Word '(1)' has a confidence of 0.977
# ...Word 'has' has a confidence of 0.997
# ...Word 'filed' has a confidence of 0.995
# ...Word 'all' has a confidence of 0.995
# ...Word 'reports' has a confidence of 0.993
# ...Word 'required' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.998
# ...Word 'be' has a confidence of 0.996
# ...Word 'filed' has a confidence of 0.995
# ...Word 'by' has a confidence of 0.997
# ...Word 'Section' has a confidence of 0.995
# ...Word '13' has a confidence of 0.995
# ...Word 'or' has a confidence of 0.995
# ...Word '15(d)' has a confidence of 0.977
# ...Word 'of' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.993
# ...Word 'Securities' has a confidence of 0.992
# ...Word 'Exchange' has a confidence of 0.995
# ...Word 'Act' has a confidence of 0.998
# ...Word 'of' has a confidence of 0.996
# ...Word '1934' has a confidence of 0.992
# ...Word 'during' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.999
# ...Word 'preceding' has a confidence of 0.992
# ...Word '12' has a confidence of 0.991
# ...Word 'months' has a confidence of 0.995
# ...Word '(or' has a confidence of 0.984
# ...Word 'for' has a confidence of 0.998
# ...Word 'such' has a confidence of 0.992
# ...Word 'shorter' has a confidence of 0.993
# ...Word 'period' has a confidence of 0.994
# ...Word 'that' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.996
# ...Word 'registrant' has a confidence of 0.992
# ...Word 'was' has a confidence of 0.997
# ...Word 'required' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.998
# ...Word 'file' has a confidence of 0.989
# ...Word 'such' has a confidence of 0.992
# ...Word 'reports),' has a confidence of 0.985
# ...Word 'and' has a confidence of 0.995
# ...Word '(2)' has a confidence of 0.995
# ...Word 'has' has a confidence of 0.992
# ...Word 'been' has a confidence of 0.992
# ...Word 'subject' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.999
# ...Word 'such' has a confidence of 0.992
# ...Word 'filing' has a confidence of 0.995
# ...Word 'requirements' has a confidence of 0.993
# ...Word 'for' has a confidence of 0.998
# ...Word 'the' has a confidence of 0.999
# ...Word 'past' has a confidence of 0.992
# ...Word '90' has a confidence of 0.998
# ...Word 'days.' has a confidence of 0.995
# ...Word 'Yes' has a confidence of 0.998
# ...Word 'No' has a confidence of 0.992
# ...Word 'Indicate' has a confidence of 0.992
# ...Word 'by' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.997
# ...Word 'mark' has a confidence of 0.992
# ...Word 'whether' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.999
# ...Word 'registrant' has a confidence of 0.992
# ...Word 'has' has a confidence of 0.998
# ...Word 'submitted' has a confidence of 0.993
# ...Word 'electronically' has a confidence of 0.992
# ...Word 'every' has a confidence of 0.996
# ...Word 'Interactive' has a confidence of 0.992
# ...Word 'Data' has a confidence of 0.99
# ...Word 'File' has a confidence of 0.993
# ...Word 'required' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.998
# ...Word 'be' has a confidence of 0.996
# ...Word 'submitted' has a confidence of 0.993
# ...Word 'pursuant' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.998
# ...Word 'Rule' has a confidence of 0.992
# ...Word '405' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.997
# ...Word 'Regulation' has a confidence of 0.992
# ...Word 'S-T' has a confidence of 0.993
# ...Word '(§232.405' has a confidence of 0.944
# ...Word 'of' has a confidence of 0.996
# ...Word 'this' has a confidence of 0.992
# ...Word 'chapter)' has a confidence of 0.994
# ...Word 'during' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.999
# ...Word 'preceding' has a confidence of 0.994
# ...Word '12' has a confidence of 0.994
# ...Word 'months' has a confidence of 0.996
# ...Word '(or' has a confidence of 0.995
# ...Word 'for' has a confidence of 0.998
# ...Word 'such' has a confidence of 0.992
# ...Word 'shorter' has a confidence of 0.994
# ...Word 'period' has a confidence of 0.994
# ...Word 'that' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.995
# ...Word 'registrant' has a confidence of 0.992
# ...Word 'was' has a confidence of 0.998
# ...Word 'required' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.998
# ...Word 'submit' has a confidence of 0.993
# ...Word 'such' has a confidence of 0.992
# ...Word 'files).' has a confidence of 0.992
# ...Word 'Yes' has a confidence of 0.996
# ...Word 'No' has a confidence of 0.997
# ...Word 'Indicate' has a confidence of 0.992
# ...Word 'by' has a confidence of 0.997
# ...Word 'check' has a confidence of 0.998
# ...Word 'mark' has a confidence of 0.992
# ...Word 'whether' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.999
# ...Word 'registrant' has a confidence of 0.993
# ...Word 'is' has a confidence of 0.998
# ...Word 'a' has a confidence of 0.995
# ...Word 'large' has a confidence of 0.995
# ...Word 'accelerated' has a confidence of 0.995
# ...Word 'filer,' has a confidence of 0.994
# ...Word 'an' has a confidence of 0.998
# ...Word 'accelerated' has a confidence of 0.994
# ...Word 'filer,' has a confidence of 0.992
# ...Word 'a' has a confidence of 0.995
# ...Word 'non-accelerated' has a confidence of 0.992
# ...Word 'filer,' has a confidence of 0.993
# ...Word 'a' has a confidence of 0.995
# ...Word 'smaller' has a confidence of 0.996
# ...Word 'reporting' has a confidence of 0.995
# ...Word 'company,' has a confidence of 0.992
# ...Word 'or' has a confidence of 0.997
# ...Word 'an' has a confidence of 0.998
# ...Word 'emerging' has a confidence of 0.992
# ...Word 'growth' has a confidence of 0.996
# ...Word 'company.' has a confidence of 0.994
# ...Word 'See' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.998
# ...Word 'definitions' has a confidence of 0.992
# ...Word 'of' has a confidence of 0.997
# ...Word '"large' has a confidence of 0.941
# ...Word 'accelerated' has a confidence of 0.992
# ...Word 'filer,"' has a confidence of 0.974
# ...Word '"accelerated' has a confidence of 0.951
# ...Word 'filer,"' has a confidence of 0.961
# ...Word '"smaller' has a confidence of 0.963
# ...Word 'reporting' has a confidence of 0.993
# ...Word 'company,"' has a confidence of 0.949
# ...Word 'and' has a confidence of 0.998
# ...Word '"emerging' has a confidence of 0.957
# ...Word 'growth' has a confidence of 0.998
# ...Word 'company"' has a confidence of 0.975
# ...Word 'in' has a confidence of 0.997
# ...Word 'Rule' has a confidence of 0.992
# ...Word '12b-2' has a confidence of 0.992
# ...Word 'of' has a confidence of 0.998
# ...Word 'the' has a confidence of 0.999
# ...Word 'Exchange' has a confidence of 0.995
# ...Word 'Act.' has a confidence of 0.989
# ...Word 'Large' has a confidence of 0.993
# ...Word 'accelerated' has a confidence of 0.993
# ...Word 'filer' has a confidence of 0.995
# ...Word 'Non-accelerated' has a confidence of 0.992
# ...Word 'filer' has a confidence of 0.996
# ...Word 'Accelerated' has a confidence of 0.993
# ...Word 'filer' has a confidence of 0.996
# ...Word 'Smaller' has a confidence of 0.995
# ...Word 'reporting' has a confidence of 0.995
# ...Word 'company' has a confidence of 0.997
# ...Word 'Emerging' has a confidence of 0.995
# ...Word 'growth' has a confidence of 0.999
# ...Word 'company' has a confidence of 0.999
# ...Word 'If' has a confidence of 0.955
# ...Word 'an' has a confidence of 0.998
# ...Word 'emerging' has a confidence of 0.992
# ...Word 'growth' has a confidence of 0.997
# ...Word 'company,' has a confidence of 0.992
# ...Word 'indicate' has a confidence of 0.993
# ...Word 'by' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.995
# ...Word 'mark' has a confidence of 0.992
# ...Word 'if' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.999
# ...Word 'registrant' has a confidence of 0.993
# ...Word 'has' has a confidence of 0.998
# ...Word 'elected' has a confidence of 0.993
# ...Word 'not' has a confidence of 0.997
# ...Word 'to' has a confidence of 0.998
# ...Word 'use' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.999
# ...Word 'extended' has a confidence of 0.995
# ...Word 'transition' has a confidence of 0.994
# ...Word 'period' has a confidence of 0.993
# ...Word 'for' has a confidence of 0.999
# ...Word 'complying' has a confidence of 0.995
# ...Word 'with' has a confidence of 0.992
# ...Word 'any' has a confidence of 0.998
# ...Word 'new' has a confidence of 0.992
# ...Word 'or' has a confidence of 0.995
# ...Word 'revised' has a confidence of 0.993
# ...Word 'financial' has a confidence of 0.992
# ...Word 'accounting' has a confidence of 0.994
# ...Word 'standards' has a confidence of 0.994
# ...Word 'provided' has a confidence of 0.995
# ...Word 'pursuant' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.996
# ...Word 'Section' has a confidence of 0.995
# ...Word '13(a)' has a confidence of 0.989
# ...Word 'of' has a confidence of 0.998
# ...Word 'the' has a confidence of 0.998
# ...Word 'Exchange' has a confidence of 0.995
# ...Word 'Act.' has a confidence of 0.991
# ...Word 'Indicate' has a confidence of 0.992
# ...Word 'by' has a confidence of 0.996
# ...Word 'check' has a confidence of 0.995
# ...Word 'mark' has a confidence of 0.992
# ...Word 'whether' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.999
# ...Word 'registrant' has a confidence of 0.992
# ...Word 'is' has a confidence of 0.997
# ...Word 'a' has a confidence of 0.995
# ...Word 'shell' has a confidence of 0.996
# ...Word 'company' has a confidence of 0.994
# ...Word '(as' has a confidence of 0.978
# ...Word 'defined' has a confidence of 0.994
# ...Word 'in' has a confidence of 0.996
# ...Word 'Rule' has a confidence of 0.992
# ...Word '12b-2' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.998
# ...Word 'Exchange' has a confidence of 0.992
# ...Word 'Act).' has a confidence of 0.982
# ...Word 'Yes' has a confidence of 0.996
# ...Word 'No' has a confidence of 0.993
# ...Word 'Indicate' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.999
# ...Word 'number' has a confidence of 0.996
# ...Word 'of' has a confidence of 0.998
# ...Word 'shares' has a confidence of 0.993
# ...Word 'outstanding' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.997
# ...Word 'each' has a confidence of 0.989
# ...Word 'of' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.996
# ...Word 'issuer's' has a confidence of 0.992
# ...Word 'classes' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.996
# ...Word 'common' has a confidence of 0.996
# ...Word 'stock,' has a confidence of 0.994
# ...Word 'as' has a confidence of 0.997
# ...Word 'of' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.996
# ...Word 'latest' has a confidence of 0.994
# ...Word 'practicable' has a confidence of 0.993
# ...Word 'date.' has a confidence of 0.992
# ...Word 'Class' has a confidence of 0.995
# ...Word 'Outstanding' has a confidence of 0.994
# ...Word 'as' has a confidence of 0.997
# ...Word 'of' has a confidence of 0.998
# ...Word 'April' has a confidence of 0.994
# ...Word '24,' has a confidence of 0.995
# ...Word '2020' has a confidence of 0.99
# ...Word 'Common' has a confidence of 0.993
# ...Word 'Stock,' has a confidence of 0.994
# ...Word '$0.00000625' has a confidence of 0.993
# ...Word 'par' has a confidence of 0.995
# ...Word 'value' has a confidence of 0.996
# ...Word 'per' has a confidence of 0.997
# ...Word 'share' has a confidence of 0.997
# ...Word '7,583,440,247' has a confidence of 0.992
# ...Word 'shares' has a confidence of 0.995
# ----------------------------------------
